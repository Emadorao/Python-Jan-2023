# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#import missingno as mns
import plotly.express  as px
# %matplotlib inline

# %%
gdp=pd.read_csv('RealGDP08062020.csv')

# %%
gdp.head()
# Out:
#    tyear  Period  Agriculture  CropProduction  Livestock  Forestry   Fishing  \
# 0   1981  Annual   2364373.15      1854764.44  341411.50  77897.99  90299.23
# 1   1982  Annual   2425960.89      1897078.85  361115.70  73910.25  93856.08
# 2   1983  Annual   2409081.92      1842704.31  393131.01  75282.78  97963.82
# 3   1984  Annual   2303505.42      1759115.15  399685.38  76694.14  68010.74
# 4   1985  Annual   2731062.47      2180907.71  428102.85  78082.45  43969.46
#
#      Industry  CrudePetroleumAndNaturalGas  SolidMinerals  ...  \
# 0  6603250.12                   4977416.70       67136.73  ...
# 1  6272828.03                   4453093.63       54840.50  ...
# 2  5264881.39                   4052977.68       44014.84  ...
# 3  5621181.44                   4559196.21       43078.37  ...
# 4  6379599.38                   4918272.50       44539.09  ...
#
#    FinanceAndInsurance  RealEstate  \
# 0            282170.74  1063959.81
# 1            372267.76  1074049.33
# 2            336896.50  1086703.98
# 3            267287.62  1086931.99
# 4            254993.44  1091378.22
#
#    ProfessionalScientificAndTechnicalServices  \
# 0                                   421381.98
# 1                                   423670.54
# 2                                   481170.73
# 3                                   518359.90
# 4                                   602464.66
#
#    AdministrativeAndSupportServicesBusinessServices  PublicAdministration  \
# 0                                           3234.81             807075.54
# 1                                           3252.38             825921.69
# 2                                           3693.79             844767.84
# 3                                           3979.28             863613.99
# 4                                           4624.92             882460.14
#
#    Education  HumanHealthAndSocialServices  ArtsEntertainmentAndRecreation  \
# 0  242555.85                     110697.65                         4561.07
# 1  248219.81                     113282.57                         4597.76
# 2  253883.77                     115867.49                         4324.58
# 3  259547.73                     118452.41                         3543.43
# 4  265211.69                     121037.33                         3395.55
#
#    OtherServices    TOTAL_GDP
# 0      132700.20  15258004.34
# 1      133767.58  14985078.32
# 2      125819.69  13849725.17
# 3      103092.67  13779255.49
# 4       98790.30  14953913.05
#
# [5 rows x 28 columns]

# %%
gdp.drop('tyear',axis=1, inplace=True)
gdp.drop('Period',axis=1, inplace=True)

# %%
gdp.head()
# Out:
#    Agriculture  CropProduction  Livestock  Forestry   Fishing    Industry  \
# 0   2364373.15      1854764.44  341411.50  77897.99  90299.23  6603250.12
# 1   2425960.89      1897078.85  361115.70  73910.25  93856.08  6272828.03
# 2   2409081.92      1842704.31  393131.01  75282.78  97963.82  5264881.39
# 3   2303505.42      1759115.15  399685.38  76694.14  68010.74  5621181.44
# 4   2731062.47      2180907.71  428102.85  78082.45  43969.46  6379599.38
#
#    CrudePetroleumAndNaturalGas  SolidMinerals  Manufacturing  Construction  \
# 0                   4977416.70       67136.73     1558696.70     851561.61
# 1                   4453093.63       54840.50     1764893.89     679200.42
# 2                   4052977.68       44014.84     1167888.87     598782.27
# 3                   4559196.21       43078.37     1018906.87     488143.29
# 4                   4918272.50       44539.09     1416787.79     336270.79
#
#    ...  FinanceAndInsurance  RealEstate  \
# 0  ...            282170.74  1063959.81
# 1  ...            372267.76  1074049.33
# 2  ...            336896.50  1086703.98
# 3  ...            267287.62  1086931.99
# 4  ...            254993.44  1091378.22
#
#    ProfessionalScientificAndTechnicalServices  \
# 0                                   421381.98
# 1                                   423670.54
# 2                                   481170.73
# 3                                   518359.90
# 4                                   602464.66
#
#    AdministrativeAndSupportServicesBusinessServices  PublicAdministration  \
# 0                                           3234.81             807075.54
# 1                                           3252.38             825921.69
# 2                                           3693.79             844767.84
# 3                                           3979.28             863613.99
# 4                                           4624.92             882460.14
#
#    Education  HumanHealthAndSocialServices  ArtsEntertainmentAndRecreation  \
# 0  242555.85                     110697.65                         4561.07
# 1  248219.81                     113282.57                         4597.76
# 2  253883.77                     115867.49                         4324.58
# 3  259547.73                     118452.41                         3543.43
# 4  265211.69                     121037.33                         3395.55
#
#    OtherServices    TOTAL_GDP
# 0      132700.20  15258004.34
# 1      133767.58  14985078.32
# 2      125819.69  13849725.17
# 3      103092.67  13779255.49
# 4       98790.30  14953913.05
#
# [5 rows x 26 columns]

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 26 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Agriculture                                       77 non-null     float64
#  1   CropProduction                                    77 non-null     float64
#  2   Livestock                                         77 non-null     float64
#  3   Forestry                                          77 non-null     float64
#  4   Fishing                                           77 non-null     float64
#  5   Industry                                          77 non-null     float64
#  6   CrudePetroleumAndNaturalGas                       77 non-null     float64
#  7   SolidMinerals                                     77 non-null     float64
#  8   Manufacturing                                     77 non-null     float64
#  9   Construction                                      77 non-null     float64
#  10  Trade                                             77 non-null     float64
#  11  Services                                          77 non-null     float64
#  12  Transport                                         77 non-null     float64
#  13  InformationAndCommunication                       77 non-null     float64
#  14  Utilities                                         77 non-null     float64
#  15  AccommodationAndFoodServices                      77 non-null     float64
#  16  FinanceAndInsurance                               77 non-null     float64
#  17  RealEstate                                        77 non-null     float64
#  18  ProfessionalScientificAndTechnicalServices        77 non-null     float64
#  19  AdministrativeAndSupportServicesBusinessServices  77 non-null     float64
#  20  PublicAdministration                              77 non-null     float64
#  21  Education                                         77 non-null     float64
#  22  HumanHealthAndSocialServices                      77 non-null     float64
#  23  ArtsEntertainmentAndRecreation                    77 non-null     float64
#  24  OtherServices                                     77 non-null     float64
#  25  TOTAL_GDP                                         77 non-null     float64
# dtypes: float64(26)
# memory usage: 15.8 KB

# %%
gdp.columns
# Out:
# Index(['Agriculture', 'CropProduction', 'Livestock', 'Forestry', 'Fishing',
#        'Industry', 'CrudePetroleumAndNaturalGas', 'SolidMinerals',
#        'Manufacturing', 'Construction', 'Trade', 'Services', 'Transport',
#        'InformationAndCommunication', 'Utilities',
#        'AccommodationAndFoodServices', 'FinanceAndInsurance', 'RealEstate',
#        'ProfessionalScientificAndTechnicalServices',
#        'AdministrativeAndSupportServicesBusinessServices',
#        'PublicAdministration', 'Education', 'HumanHealthAndSocialServices',
#        'ArtsEntertainmentAndRecreation', 'OtherServices', 'TOTAL_GDP'],
#       dtype='object')

# %%
gdp.head()
# Out:
#    Agriculture  CropProduction  Livestock  Forestry   Fishing    Industry  \
# 0   2364373.15      1854764.44  341411.50  77897.99  90299.23  6603250.12
# 1   2425960.89      1897078.85  361115.70  73910.25  93856.08  6272828.03
# 2   2409081.92      1842704.31  393131.01  75282.78  97963.82  5264881.39
# 3   2303505.42      1759115.15  399685.38  76694.14  68010.74  5621181.44
# 4   2731062.47      2180907.71  428102.85  78082.45  43969.46  6379599.38
#
#    CrudePetroleumAndNaturalGas  SolidMinerals  Manufacturing  Construction  \
# 0                   4977416.70       67136.73     1558696.70     851561.61
# 1                   4453093.63       54840.50     1764893.89     679200.42
# 2                   4052977.68       44014.84     1167888.87     598782.27
# 3                   4559196.21       43078.37     1018906.87     488143.29
# 4                   4918272.50       44539.09     1416787.79     336270.79
#
#    ...  FinanceAndInsurance  RealEstate  \
# 0  ...            282170.74  1063959.81
# 1  ...            372267.76  1074049.33
# 2  ...            336896.50  1086703.98
# 3  ...            267287.62  1086931.99
# 4  ...            254993.44  1091378.22
#
#    ProfessionalScientificAndTechnicalServices  \
# 0                                   421381.98
# 1                                   423670.54
# 2                                   481170.73
# 3                                   518359.90
# 4                                   602464.66
#
#    AdministrativeAndSupportServicesBusinessServices  PublicAdministration  \
# 0                                           3234.81             807075.54
# 1                                           3252.38             825921.69
# 2                                           3693.79             844767.84
# 3                                           3979.28             863613.99
# 4                                           4624.92             882460.14
#
#    Education  HumanHealthAndSocialServices  ArtsEntertainmentAndRecreation  \
# 0  242555.85                     110697.65                         4561.07
# 1  248219.81                     113282.57                         4597.76
# 2  253883.77                     115867.49                         4324.58
# 3  259547.73                     118452.41                         3543.43
# 4  265211.69                     121037.33                         3395.55
#
#    OtherServices    TOTAL_GDP
# 0      132700.20  15258004.34
# 1      133767.58  14985078.32
# 2      125819.69  13849725.17
# 3      103092.67  13779255.49
# 4       98790.30  14953913.05
#
# [5 rows x 26 columns]

# %%
X=gdp.drop('TOTAL_GDP',axis=1)
y=gdp['TOTAL_GDP']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
pred= model.predict(X_test)

# %%
pred
# Out:
# array([14304438.43672264, 59929893.03979751, 42922407.9198703 ,
#        16434552.66906805, 69023929.9438914 , 15943714.53044323,
#        17555441.68979758, 17479127.56443724, 14819619.25961807,
#        18533752.05719617, 19199060.32297308, 67152785.8400185 ,
#        13450716.67835474, 13849725.16647326, 18081342.09598425,
#        46012515.31696104])

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 1.0

# %%
print(model.coef_)
# Out:
# [0.45293942 0.54706058 0.54706054 0.54706114 0.54706059 0.81760691
#  0.18239309 0.18239295 0.18239309 0.99999999 1.         0.79888555
#  0.20111441 0.20111446 0.20111444 0.20111451 0.20111446 0.20111445
#  0.20111443 0.20111922 0.20111448 0.20111447 0.201114   0.20111489
#  0.20111445]

# %%
print(model.intercept_)
# Out:
# 0.0009512566030025482

# %%
coef=pd.DataFrame(data=model.coef_, index=X.columns, columns=['Coefficient'])

# %%
coef
# Out:
#                                                   Coefficient
# Agriculture                                          0.452939
# CropProduction                                       0.547061
# Livestock                                            0.547061
# Forestry                                             0.547061
# Fishing                                              0.547061
# Industry                                             0.817607
# CrudePetroleumAndNaturalGas                          0.182393
# SolidMinerals                                        0.182393
# Manufacturing                                        0.182393
# Construction                                         1.000000
# Trade                                                1.000000
# Services                                             0.798886
# Transport                                            0.201114
# InformationAndCommunication                          0.201114
# Utilities                                            0.201114
# AccommodationAndFoodServices                         0.201115
# FinanceAndInsurance                                  0.201114
# RealEstate                                           0.201114
# ProfessionalScientificAndTechnicalServices           0.201114
# AdministrativeAndSupportServicesBusinessServices     0.201119
# PublicAdministration                                 0.201114
# Education                                            0.201114
# HumanHealthAndSocialServices                         0.201114
# ArtsEntertainmentAndRecreation                       0.201115
# OtherServices                                        0.201114

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print(mean_absolute_error(y_test,pred))
# Out:
# 0.005888566607609391

# %%
print(mean_squared_error(y_test,pred))
# Out:
# 6.739682176645865e-05

# %%
sns.regplot(y_test,pred)
# Out:
# C:\Users\Emadora\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TOTAL_GDP'>

# %%
print(np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.008209556733859548
